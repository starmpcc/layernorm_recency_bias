# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import math
import seaborn  # For rocket colormap
from mpl_toolkits.axes_grid1 import make_axes_locatable

plt.rcParams["axes.titlesize"] = 20
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14


class SimpleResModel(nn.Module):
    def __init__(self, dim=256):
        super().__init__()
        self.ln = nn.LayerNorm(dim, elementwise_affine=False, bias=False, eps=1e-12)

    def forward(self, x, layernorm=False, residual=False):
        B, S, E = x.size()
        hidden = x
        if layernorm:
            hidden = self.ln(hidden)

        attn = hidden @ hidden.mT / (E**0.5)

        mask = torch.zeros(S, S, device=x.device)
        mask = torch.masked_fill(
            mask, torch.ones_like(mask).triu(1).bool(), float("-inf")
        )
        attn = attn + mask.unsqueeze(0)

        _out = F.softmax(attn, dim=-1)

        out = _out @ hidden
        if residual:
            out += x
        return out, attn, _out


def get_recency_prob(attn):
    B, S, _ = attn.shape
    if S == 0:
        return 0.0

    tot = B * S * (S - 1) * (S - 2) // 6

    A_k = attn.unsqueeze(2)  # (B, S, 1, S)
    A_j = attn.unsqueeze(3)  # (B, S, S, 1)

    i_idx = torch.arange(S, device=attn.device).view(S, 1, 1)
    j_idx = torch.arange(S, device=attn.device).view(1, S, 1)
    k_idx = torch.arange(S, device=attn.device).view(1, 1, S)

    mask = (i_idx > k_idx) & (j_idx < k_idx)

    cnt = ((A_k > A_j) & mask).sum().item()
    return cnt / tot


def run_layers(alpha, layernorm, residual, d=64, num_layers=4, B=10000000, S=10):
    """Run the model and return attention scores for all layers."""
    E = d
    layer = SimpleResModel(E)
    m = 1
    if alpha == 1:
        l = 1
        m = 0
    elif alpha == 0:
        l = 0
        m = 1
    else:
        l = math.sqrt(alpha / (1 - alpha))

    out = m * torch.randn(B, S, E) + l * torch.randn(B, 1, E)
    out = out / math.sqrt(E)

    all_attn = []
    for i in range(num_layers):
        out, attn, _attn = layer(out, layernorm=layernorm, residual=residual)
        all_attn.append(attn)
    return all_attn


# Shared layout constants
_ADJ = dict(left=0.01, right=0.99, top=0.96, bottom=0.01, wspace=0.35, hspace=0.12)
_PAD_INCHES = 0.01


def _plot_heatmap(fig, ax, attn, rp, is_top_row, is_left_col, n_rows, row, title=None, ylabel=None):
    """Shared heatmap plotting logic for both make_figure and plot_theory."""
    inner = attn.mean(0)

    cmap = plt.cm.get_cmap("rocket")
    cmap.set_over("white")
    im = ax.imshow(inner.detach().cpu().numpy(), cmap=cmap, aspect="equal")

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="4%", pad=0.02)
    fig.colorbar(im, cax=cax)

    unique_vals = inner.unique()
    if len(unique_vals) >= 2:
        im.set_clim(None, torch.topk(unique_vals, 2)[0][-1].item())

    if is_top_row and title:
        ax.set_title(title, pad=8)

    if is_left_col and ylabel:
        ax.set_ylabel(ylabel, rotation=90, labelpad=3)

    # Hide tick labels on non-left-col axes to reduce col gap
    if not is_left_col:
        ax.set_yticks([])

    ax.text(0.95, 0.05, f"RP={rp:.4f}", transform=ax.transAxes,
            fontsize=16, ha="right", va="bottom",
            bbox=dict(boxstyle="round,pad=0.15", facecolor="white", alpha=0.8))


def make_figure(dims, layer_indices, save_path, configs=None, B=10000000):
    if configs is None:
        configs = [
            {"alpha": 0.0, "layernorm": False, "residual": False, "label": r"$\alpha$=0, noLN, noRes"},
            {"alpha": 0.0, "layernorm": True,  "residual": False, "label": r"$\alpha$=0, LN, noRes"},
            {"alpha": 0.5, "layernorm": True,  "residual": False, "label": r"$\alpha$=0.5, LN, noRes"},
            {"alpha": 0.5, "layernorm": True,  "residual": True,  "label": r"$\alpha$=0.5, LN, Res"},
        ]

    n_rows = len(configs)
    n_layers = len(layer_indices)
    n_dim_groups = len(dims)
    n_cols = n_dim_groups * n_layers

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(3.8 * n_cols, 3.5 * n_rows))
    if n_rows == 1:
        axes = axes[None, :]
    if n_cols == 1:
        axes = axes[:, None]

    for row, cfg in enumerate(configs):
        for di, d in enumerate(dims):
            all_attn = run_layers(
                alpha=cfg["alpha"],
                layernorm=cfg["layernorm"],
                residual=cfg["residual"],
                d=d,
                num_layers=max(layer_indices) + 1,
                B=B,
            )
            for li, layer_idx in enumerate(layer_indices):
                col = di * n_layers + li
                ax = axes[row, col]
                attn = all_attn[layer_idx]
                rp = get_recency_prob(attn)

                _plot_heatmap(
                    fig, ax, attn, rp,
                    is_top_row=(row == 0),
                    is_left_col=(col == 0),
                    n_rows=n_rows, row=row,
                    title=f"d={d}, Layer {layer_idx+1}",
                    ylabel=cfg["label"],
                )

    fig.subplots_adjust(**_ADJ)
    plt.savefig(save_path, bbox_inches="tight", pad_inches=_PAD_INCHES)
    plt.show()
    print(f"Saved to {save_path}")


def plot_theory(alpha, row, layernorm, total_rows, configs, residual=False, num_layers=4, d=64, B=10000000):
    """Plot a single row of the appendix figure using the same style as make_figure."""
    S, E = 10, d
    fig = plt.gcf()

    layer = SimpleResModel(E)
    m = 1
    if alpha == 1:
        l = 1
        m = 0
    elif alpha == 0:
        l = 0
        m = 1
    else:
        l = math.sqrt(alpha / (1 - alpha))

    out = m * torch.randn(B, S, E) + l * torch.randn(B, 1, E)
    out = out / math.sqrt(E)

    ln_label = "LN" if True else "noLN"
    res_label = "Res" if residual else "noRes"
    row_label = rf"$\alpha$={alpha}, {ln_label}, {res_label}"

    for i in range(num_layers):
        out, attn, _attn = layer(out, layernorm=True, residual=residual)
        ax = plt.subplot(total_rows, num_layers, row * num_layers + i + 1)
        rp = get_recency_prob(attn)

        _plot_heatmap(
            fig, ax, attn, rp,
            is_top_row=(row == 0),
            is_left_col=(i == 0),
            n_rows=total_rows, row=row,
            title=f"Layer {i+1}",
            ylabel=row_label,
        )

# %%
# Figure 1: d=16 and d=64, Layers 1 & 2
make_figure(
    dims=[16, 64], layer_indices=[0, 1], save_path="../figures/fig1_d16_d64_L1L2.pdf"
)
# Out:
# /tmp/ipykernel_2220220/4044170936.py:95: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("rocket")
# Saved to ../figures/fig1_d16_d64_L1L2.pdf

# %%
# Figure 2: d=256 and d=1024, Layers 1 & 2
make_figure(
    dims=[256, 1024],
    layer_indices=[0, 1],
    save_path="../figures/fig2_d256_d1024_L1L2.pdf",
)
# Out:
# /tmp/ipykernel_2220220/4044170936.py:95: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("rocket")
# Saved to ../figures/fig2_d256_d1024_L1L2.pdf

# %%
# Figure 3: d=16 and d=64, Layers 3 & 4 (Appendix)
make_figure(
    dims=[16, 64], layer_indices=[2, 3], save_path="../figures/fig3_d16_d64_L3L4.pdf"
)
# Out:
# /tmp/ipykernel_2220220/4044170936.py:95: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("rocket")
# Saved to ../figures/fig3_d16_d64_L3L4.pdf

# %%
# Appendix: Multiple alphas with d=16, LN, noRes
fig = plt.figure(figsize=(3.8 * 4, 3.5 * 4))
plot_theory(0.2, 0, True, 4, configs=None, d=16)
plot_theory(0.4, 1, True, 4, configs=None, d=16)
plot_theory(0.6, 2, True, 4, configs=None, d=16)
plot_theory(0.8, 3, True, 4, configs=None, d=16)
fig.subplots_adjust(**_ADJ)
plt.savefig("../figures/simul_alpha.pdf", bbox_inches="tight", pad_inches=_PAD_INCHES)
# Out:
# /tmp/ipykernel_2220220/4044170936.py:95: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("rocket")

# %%
# Appendix: Multiple alphas with d=16, LN, Res (residual)
fig = plt.figure(figsize=(3.8 * 4, 3.5 * 5))
plot_theory(0.0, 0, True, 5, configs=None, residual=True, d=16)
plot_theory(0.2, 1, True, 5, configs=None, residual=True, d=16)
plot_theory(0.4, 2, True, 5, configs=None, residual=True, d=16)
plot_theory(0.6, 3, True, 5, configs=None, residual=True, d=16)
plot_theory(0.8, 4, True, 5, configs=None, residual=True, d=16)
fig.subplots_adjust(**_ADJ)
plt.savefig("../figures/simul_alpha_residual.pdf", bbox_inches="tight", pad_inches=_PAD_INCHES)
# Out:
# /tmp/ipykernel_2220220/4044170936.py:95: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("rocket")
